# %% [markdown]
# # New section
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# # Project Title
#
# Water Consumption and Cost Analysis

# %% [markdown]
# # Domain
# Environmental  Data Analytics(Water Consumption & Sustainability)

# %% [markdown]
# # Objective
#
# 1. To identify meaningful patterns, and insights in water consumption data (2020_2024)
#
#
# 2. To clean, transform, and preprocess the unclean dataset for analysis.
#
# 3. To create meaningful visualizations that clearly explain water consumption trends across years,boroughs and property types.
#
# 4. To provide actionable insights and recommendations for sustainable water management.

# %% [markdown]
# # Outcome
#
# The project helps uncover key patterns, trends, and hidden insights in water consumption.The analysis provides a clear understanding of:
# -----------------------------------------------------------------------------
#        *Which areas or property types consume the most water.
#        *How  cost vary with consumption.
#        *Yearly consumption trends.

# %% [markdown]
# #Dataset Information
#
# Source: Data.gov(NYC Open Data Portal)
#
# Year / Timeline: Data collected from 2020 to 2024
#
# Dataset Description:
# |Column name       |Description
# |------------------|-------------------------------------
# |Year              |Year of record
# |Borough           |Area within the city
# |Development       |Type of development(Residenncial,Industrial,Government)
# |ZipCode           |Postal code of the property.
# |Property type     |Type of Building(Apartment,House,Office,School,Hospital)
# |Meter Type        |Meter type (Digital,Analog,Smart)
# |Customerclass     |Customer Category(Domestic,Industrial,Commercial)
# |ConsumptionGallons|Amount of water consumed(gallons)
# |CostUSD           |Cost of water consumption(USD)
# |Notes             |Miscellaneous notes or flags
#
#
#
# Name - It tells us about the water consumption

# %% [markdown]
# #Type of Analysis
#
# This Project is a Descriptive Analysis as it focuses on summarizing  and understanding past water consumption patterns between 2020-2024.

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
# ##Define the business problem and expected outcome
#
# Water is a critical environmental resource,and monitoring its usage is essential for sustainabilty.This project focusus on analysing **urban water consumption data to**:
#
# -Identitify consumption trends over the years.
#
#
# -Compare water usage across boroughs,property types,and customer categories
#
#
# -Study the relationship between water consumption and cost
#
#
# -Provide actionable insights for sustainable water management and cost reduction.
#
# ##Expected Outcomes
#
# -Discover high-consumption areas and inefficient usage patterns
#
# -Provide recommendations to improve water efficiency and conservation
#
#
#
#
# ##Choose dataset and explain its source, size, and features
#
# ***Sourse**: Simul;ated dataset for academic project (structured like open environmental datadets).
#
# ***File Name** :water _consumption_2020_2024_uncleaned.csv
#
#
# ***Size** 500 rows x 10 columns
#
# ***Features(Columns)**:Year,borough,Development,Zipcode,PropertyType,MeterType,CustomerClass,ConsumptionGallons,CostUSD,Notes.
#
# ##Import libraries, load dataset
#
# ##Dataset description (rows, columns, features)
#
# ##Initial EDA (head, info, describe, shape, null checks)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3ec82128-32be-4f44-8340-de9324068eb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ec82128-32be-4f44-8340-de9324068eb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('water_consumption_2020_2024_uncleaned.csv')
df.head()
# Out:
#    Year        Borough Development  ZipCode PropertyType MeterType  \
# 0  2023          Bronx  Government    11201     Hospital     Smart
# 1  2024      Manhattan  Government    11368       School    Analog
# 2  2022  Staten Island  Government    11201        House    Analog
# 3  2024         Queens  Government    11201        House   Digital
# 4  2024         Queens  Government    11368       School   Digital
#
#   CustomerClass  ConsumptionGallons     CostUSD    Notes
# 0    Commercial             49456.0         NaN  pending
# 1    Commercial             35631.0  105.578169  pending
# 2    Commercial             17499.0   57.237257  pending
# 3    Industrial             40852.0   89.116326       ok
# 4      Domestic              9016.0   18.620167      NaN

# %%
print("=====First 5 Rows=====")
print(df.head())
# Out:
# =====First 5 Rows=====
#    Year        Borough Development  ZipCode PropertyType MeterType  \
# 0  2023          Bronx  Government    11201     Hospital     Smart
# 1  2024      Manhattan  Government    11368       School    Analog
# 2  2022  Staten Island  Government    11201        House    Analog
# 3  2024         Queens  Government    11201        House   Digital
# 4  2024         Queens  Government    11368       School   Digital
#
#   CustomerClass  ConsumptionGallons     CostUSD    Notes
# 0    Commercial             49456.0         NaN  pending
# 1    Commercial             35631.0  105.578169  pending
# 2    Commercial             17499.0   57.237257  pending
# 3    Industrial             40852.0   89.116326       ok
# 4      Domestic              9016.0   18.620167      NaN

# %%
print("=====Last 5 Rows=====")
print(df.tail())
# Out:
# =====Last 5 Rows=====
#      Year        Borough  Development  ZipCode PropertyType MeterType  \
# 505  2021      Manhattan  Residential    10301        House     Smart
# 506  2022          Bronx   Government    10301     Hospital    Analog
# 507  2022          Bronx  Residential    11201    Apartment     Smart
# 508  2022  Staten Island   Government    11368     Hospital    Analog
# 509  2024      Manhattan   Industrial    11368     Hospital     Smart
#
#     CustomerClass  ConsumptionGallons     CostUSD    Notes
# 505    Commercial              3384.0    7.158533    check
# 506    Industrial             16072.0   46.427680  pending
# 507    Commercial             37703.0   96.183968      NaN
# 508    Commercial             46895.0  152.131091    check
# 509      Domestic             15482.0   61.693983    check

# %%
print("\n=====Random Sample Rows=====")
print(df.sample(5))
# Out:
# =====Random Sample Rows=====
#      Year        Borough  Development  ZipCode PropertyType MeterType  \
# 274  2022       Brooklyn   Commercial    10001        House     Smart
# 57   2021  Staten Island   Commercial    10301    Apartment     Smart
# 320  2021      Manhattan   Commercial    10453    Apartment    Analog
# 232  2023          Bronx  Residential    10301        House     Smart
# 166  2023  Staten Island   Industrial    10001    Apartment     Smart
#
#     CustomerClass  ConsumptionGallons     CostUSD    Notes
# 274    Industrial                 NaN  144.049882  pending
# 57       Domestic             11433.0   34.657068       ok
# 320    Industrial             48832.0  138.623267  pending
# 232    Commercial             16233.0   47.097987      NaN
# 166      Domestic             38496.0  149.002394      NaN

# %%
#Initial EDA Report
print("=====Dataset Shape=====")
print(df.shape)
# Out:
# =====Dataset Shape=====
# (510, 10)

# %%
print("\n=====Column & Data Types=====")
print(df.dtypes)
# Out:
# =====Column & Data Types=====
# Year                    int64
# Borough                object
# Development            object
# ZipCode                 int64
# PropertyType           object
# MeterType              object
# CustomerClass          object
# ConsumptionGallons    float64
# CostUSD               float64
# Notes                  object
# dtype: object

# %%
print("\n=====Missing Values=====")
print(df.isnull().sum())
# Out:
# =====Missing Values=====
# Year                    0
# Borough                 0
# Development             0
# ZipCode                 0
# PropertyType            0
# MeterType               0
# CustomerClass           0
# ConsumptionGallons     20
# CostUSD                16
# Notes                 138
# dtype: int64

# %%
print("\n=====Statistical Summary (Numerical Columns)=====")
print(df.describe())
# Out:
# =====Statistical Summary (Numerical Columns)=====
#               Year       ZipCode  ConsumptionGallons     CostUSD
# count   510.000000    510.000000          490.000000  494.000000
# mean   2021.986275  10665.917647        26058.789796   77.829889
# std       1.424528    525.382492        13903.881770   44.751937
# min    2020.000000  10001.000000         1159.000000    2.389529
# 25%    2021.000000  10301.000000        14337.750000   42.304120
# 50%    2022.000000  10453.000000        25496.500000   74.586765
# 75%    2023.000000  11201.000000        38154.500000  109.566609
# max    2024.000000  11368.000000        49933.000000  188.170313

# %%
print("\n=====Unique Values in Categorical Columns=====")
for column in df.select_dtypes(include=['object']).columns:
    print(f"\nUnique values in {column}:")
    print(df[column].unique())
# Out:
# =====Unique Values in Categorical Columns=====
#
# Unique values in Borough:
# ['Bronx' 'Manhattan' 'Staten Island' 'Queens' 'Brooklyn']
#
# Unique values in Development:
# ['Government' 'Residential' 'Industrial' 'Commercial']
#
# Unique values in PropertyType:
# ['Hospital' 'School' 'House' 'Apartment' 'Office']
#
# Unique values in MeterType:
# ['Smart' 'Analog' 'Digital']
#
# Unique values in CustomerClass:
# ['Commercial' 'Industrial' 'Domestic']
#
# Unique values in Notes:
# ['pending' 'ok' nan 'check']

# %%
# Shape of dataset
print("Shape of dataset:,df.shape")

#Column names
print("Column names:",df.columns.tolist())
# Out:
# Shape of dataset:,df.shape
# Column names: ['Year', 'Borough', 'Development', 'ZipCode', 'PropertyType', 'MeterType', 'CustomerClass', 'ConsumptionGallons', 'CostUSD', 'Notes']

# %%
# check dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                510 non-null    int64
#  1   Borough             510 non-null    object
#  2   Development         510 non-null    object
#  3   ZipCode             510 non-null    int64
#  4   PropertyType        510 non-null    object
#  5   MeterType           510 non-null    object
#  6   CustomerClass       510 non-null    object
#  7   ConsumptionGallons  490 non-null    float64
#  8   CostUSD             494 non-null    float64
#  9   Notes               372 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 40.0+ KB

# %%
# Summary stastics
df.describe()
# Out:
#               Year       ZipCode  ConsumptionGallons     CostUSD
# count   510.000000    510.000000          490.000000  494.000000
# mean   2021.986275  10665.917647        26058.789796   77.829889
# std       1.424528    525.382492        13903.881770   44.751937
# min    2020.000000  10001.000000         1159.000000    2.389529
# 25%    2021.000000  10301.000000        14337.750000   42.304120
# 50%    2022.000000  10453.000000        25496.500000   74.586765
# 75%    2023.000000  11201.000000        38154.500000  109.566609
# max    2024.000000  11368.000000        49933.000000  188.170313

# %%
# Null value check
df.isnull().sum()
# Out:
# Year                    0
# Borough                 0
# Development             0
# ZipCode                 0
# PropertyType            0
# MeterType               0
# CustomerClass           0
# ConsumptionGallons     20
# CostUSD                16
# Notes                 138
# dtype: int64

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# Handle missing values (impute or drop)
#
# Handle duplicates
#
# Treat outliers if required
#
# Check skewness and apply transformations
#
# Convert data types if needed
#
# Feature transformations (date parts, derived fields if required for analysis)

# %%
#Check missing values
print("=====Missing Values Before Cleaning=====")
print(df.isnull().sum())
# Out:
# =====Missing Values Before Cleaning=====
# Year                    0
# Borough                 0
# Development             0
# ZipCode                 0
# PropertyType            0
# MeterType               0
# CustomerClass           0
# ConsumptionGallons     20
# CostUSD                16
# Notes                 138
# dtype: int64

# %%
#Example:Drop rows with too many missing values
df=df.dropna(how='all')

# %%
#Example:Fill numerical columns with median
df=df.fillna(df.median(numeric_only=True))

# %%
#Example:Fill categorical columns with mode
for column in df.select_dtypes(include=['object']).columns:
    df[column]=df[column].fillna(df[column].mode()[0])

# %%
print("=====Missing Values After Cleaning=====")
print(df.isnull().sum())
# Out:
# =====Missing Values After Cleaning=====
# Year                  0
# Borough               0
# Development           0
# ZipCode               0
# PropertyType          0
# MeterType             0
# CustomerClass         0
# ConsumptionGallons    0
# CostUSD               0
# Notes                 0
# dtype: int64

# %%
#2.Handle Duplicates
print("Duplicate rows before:",
df.duplicated().sum())
df=df.drop_duplicates()
print("Duplicate rows after:",
df.duplicated().sum())
# Out:
# Duplicate rows before: 10
# Duplicate rows after: 0

# %%
#3.Treat Outliers (optional but good for water consumption data)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Example:Check distribution of "Consumption"
sns.boxplot(x=df['ConsumptionGallons'])
plt.show()

# %%
#4.Convert Data Types
#Example:Ensure Year is integer
df['Year']=df['Year'].astype(int)

# %%
#Example:Convert categorical columns to category type
cat_cols=df.select_dtypes(include=['object']).columns
df[cat_cols]=df[cat_cols].astype('category')

# %%
print(df.columns)
# Out:
# Index(['Year', 'Borough', 'Development', 'ZipCode', 'PropertyType',
#        'MeterType', 'CustomerClass', 'ConsumptionGallons', 'CostUSD', 'Notes'],
#       dtype='object')

# %%
5.#Create new feature:Cost per Unit Consumption
df['Cost_per_unit']=df['CostUSD']/(df['ConsumptionGallons']+1)
#+1to avoid division by zero

# %%
# Save cleaned dataset
df.to_csv("cleaned_dataset.csv", index=False)

# Download the cleaned dataset
from google.colab import files
files.download("cleaned_dataset.csv")

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %%
#Check columns and detect likelyconsumption/cost/year columns
print("All columns")
print(df.columns.tolist())
# Out:
# All columns
# ['Year', 'Borough', 'Development', 'ZipCode', 'PropertyType', 'MeterType', 'CustomerClass', 'ConsumptionGallons', 'CostUSD', 'Notes', 'Cost_per_unit']

# %%
# try to auto-detect likely column names
consumption_col = None
cost_col = None
year_col = None

for c in df.columns:
    lc = c.lower()
    if any(k in lc for k in ['consump', 'gallon', 'water']):
        if consumption_col is None: consumption_col = c
    if any(k in lc for k in ['cost', 'price', 'usd']):
        if cost_col is None: cost_col = c
    if 'year' in lc:
        if year_col is None: year_col = c

print("\nDetected columns (you can override these manually if needed):")
print("consumption_col ->", consumption_col)
print("cost_col        ->", cost_col)
print("year_col        ->", year_col)

# If detection failed, set them manually, e.g.
# consumption_col = 'ConsumptionGallons'
# cost_col = 'CostUSD'
# year_col = 'Year'
# Out:
# Detected columns (you can override these manually if needed):
# consumption_col -> ConsumptionGallons
# cost_col        -> CostUSD
# year_col        -> Year

# %%
#Records per year
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,4))
sns.countplot(x=year_col, data=df)
plt.title("Number of records per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation of your above chart
#
# This is bar chart and it shows the count of records grouped by year.
#
# The height of each bar represents how many entries are present in the dataset for that particular year.By sorting,we can clearly see which year has the highest and lowest number of records.
#
# Year(x-axis) and the number of records(y-axis).
#
# This bar chart shows the count of records grouped by Year.

# %%
#Distribution of Consumption
plt.figure(figsize=(8,4))
sns.histplot(df[consumption_col], bins=30, kde=True)
plt.title("Distribution of Water Consumption(Galloons)")
plt.xlabel("ConsumptionGalloons")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation of the histogram
#
# This chart is a histogram with a KDE(Kernel Density Estimate)curve showing the distribution of water consumption values across all records.
#
# *Most of the records are concentrated with a certain range of water consumption range(the tallest bars)
#
# *The KDS curve smooths out the histogram to show the overall shape of distribution(whether it is normal,skewed left/right,etc.).
#
# *If the distribution has the long tail (skewness),it indicates that while most customers consume much hiher amount.
#
#
#
# FEATURES:
# ConsumptionGallons (x-axis-> the water consumption amount )
#
# Frequency/count(y-axis-->howmany records fall into each consumption range).
#
#
#
# The histogram bars show how many customers fall into different ranges of water sonsumption(e.g., 0-10,000 gallons,10,000-20,000 gallons,ets.).
#
# The KDE(blue cure)overlays a smoothed version of the distribution to show the overall trend.
#
# Most customers seem to consume wter in the 10,000 to 30,000 gallon range, as indicated by the taller bars in that range.
#
# There is a noticeable peak around 20,000 gallons,suggesting many customers have similar consumption at the level.
#
# Some customers consume very high amounts(above 40,000 gallons),but those are fewer in number.

# %%
# Boxplot for Outliers
plt.figure(figsize=(6,3))
sns.boxplot(x=df[consumption_col].dropna())
plt.title("Boxplot of Water Consumption")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Interpretation of the Boxplot
#
# Chart type is boxplot.
#
# The box shows the middle 50% of customers' water consumption
#
# The line inside the box is the median customer value .
#
# The whiskers show the overall spread of most datapoints
#
# The dots outside whiskers represent outliers--customer who consume expceptionally high or low amounts of water compared to the majority.
#
# Feature Used:ConsumptionGallons(total water consumption).
#
# *This analysis is crucial because it shows that while most customers fall within a normal range, a small group consumes dispropertionately high amounts of water, which can help target conservation or billing strategies.

# %%
#  Category Counts (for categorical features)
print("===== Category Counts =====")

for col in df.select_dtypes(include='object').columns:
    print(f"\nColumn: {col}")
    print(df[col].value_counts().head(10))  # top 10 categories
# Out:
# ===== Category Counts =====

# %%
#Consumption and cost trend over time
# Step 5 — Trends Over Time
import matplotlib.pyplot as plt

# Group by year and take mean consumption & cost
trend = df.groupby(year_col)[[consumption_col, cost_col]].mean()

plt.figure(figsize=(10,5))
plt.plot(trend.index, trend[consumption_col], marker='o', label='Avg Consumption')
plt.plot(trend.index, trend[cost_col], marker='s', label='Avg Cost')
plt.title("Trends in Water Consumption & Cost Over Time")
plt.xlabel("Year")
plt.ylabel("Average Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation of your above chart
#
# Chart Type:Line chart
#
# This is a time trend line chart showing water consumption and cost across years.
#
# Year(x-axis).
#
# Avg Consumption(blue line,left y-axis).
#
# Avg Cost (orange line,left-axis but very small values).
#
# The chart shows that while average water consumption has fluctuated,it has generally declined from 2020 to 2024.On the other hand,average water costs remain stable and relatively low in comparision.This suggests that changes in consumption are not strongly reflected in the recorded costs,possibly due to subsidies, fixed pricing,or data scaling differences.

# %%
#Correlation and scatter plot
# Step 6 — Relationship between Consumption and Cost

# 1. Correlation check
corr = df[[consumption_col, cost_col]].corr()
print("Correlation between consumption and cost:")
print(corr)

# 2. Scatter plot
plt.figure(figsize=(7,5))
plt.scatter(df[consumption_col], df[cost_col], alpha=0.5)
plt.title("Relationship between Water Consumption and Cost")
plt.xlabel("Water Consumption (Gallons)")
plt.ylabel("Cost (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Correlation between consumption and cost:
#                     ConsumptionGallons   CostUSD
# ConsumptionGallons            1.000000  0.899631
# CostUSD                       0.899631  1.000000

# %% [markdown]
# ##Interpretation of Scatter plot
# Chart type :Scatter plot.
#
# This chart is showing the relationship between Water Consumption(Gallons) and Cost(USD)
#
# Features used:
#
# X-axis -->Water Consumption (Gallons)
#
# Y-axis -->Cost (USD)
#
# The scatter plot clearly demonstrates a strong linear relationship between water consumption and cost.Customer who consume more water consistently pay higher costs,confirming that consumption is the primary driver of water bills.

# %%
#  Grouped analysis by PropertyType
group_property = df.groupby("PropertyType")[[consumption_col, cost_col]].mean().sort_values(consumption_col, ascending=False)

print("Average Consumption and Cost by PropertyType:")
print(group_property)

# Barplot for visualization
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="PropertyType", y=consumption_col, ci=None)
plt.title("Average Water Consumption by Property Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,5))
sns.barplot(data=df, x="PropertyType", y=cost_col, ci=None)
plt.title("Average Water Cost by Property Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Average Consumption and Cost by PropertyType:
#               ConsumptionGallons    CostUSD
# PropertyType
# Hospital            26632.564220  78.254193
# House               26285.361111  79.107286
# Apartment           25911.954545  77.159402
# School              25895.128571  79.593734
# Office              25072.234177  74.217752
# /tmp/ipython-input-4207055447.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_property = df.groupby("PropertyType")[[consumption_col, cost_col]].mean().sort_values(consumption_col, ascending=False)
# /tmp/ipython-input-4207055447.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="PropertyType", y=consumption_col, ci=None)
# ...

# %% [markdown]
# ##Interpretation of Bar chart
# Chart type Bar chart
#
# This chart is showing the average water consuption for each type of property.
#
# Features used:
#
# X-axis -->Property Type(categorical feachure:e.g.,Residential,Commercial,Industrial,Institutional).
#
# Y-axis -->ConsumptionGallons (numerical feature:average water usage in gallons)
#
# Property type is a key driven of water usage-larger -scale operations like Industrial or Commercial require more water campared to smaller-scale ones like Residential.

# %% [markdown]
# ##Interpretation of Average Water Cost by Property type Bar chart
#
# This chart is showing the average water cost (in USD)for each property type.
#
# Features used:
#
# X-axis -->Property Type(categorical feachure:e.g.,Residential,Commercial,Industrial,Institutional).
#
# Y-axis --> CostUSD(numerical feature:average water cost in USD)
#
# This chart helps us identigy which property types are financially burdened more by water usage,not just in terms of gallons but in cost efficiency as well.

# %%
# Group by year to see total and average consumption & cost
yearly_trends = df.groupby(year_col).agg({
    consumption_col: ['sum', 'mean'],
    cost_col: ['sum', 'mean']
}).reset_index()

# Rename columns for clarity
yearly_trends.columns = [year_col, 'Total_Consumption', 'Avg_Consumption',
                         'Total_Cost', 'Avg_Cost']

print(yearly_trends)

# Plot yearly total consumption
plt.figure(figsize=(8,5))
sns.lineplot(data=yearly_trends, x=year_col, y="Total_Consumption", marker="o")
plt.title("Yearly Trend of Total Water Consumption")
plt.xlabel("Year")
plt.ylabel("Total Consumption (Gallons)")
plt.tight_layout()
plt.show()

# Plot yearly average cost
plt.figure(figsize=(8,5))
sns.lineplot(data=yearly_trends, x=year_col, y="Avg_Cost", marker="o", color="red")
plt.title("Yearly Trend of Average Water Cost")
plt.xlabel("Year")
plt.ylabel("Average Cost (USD)")
plt.tight_layout()
plt.show()
# Out:
#    Year  Total_Consumption  Avg_Consumption   Total_Cost   Avg_Cost
# 0  2020          3009462.5     27609.747706  8947.077007  82.083275
# 1  2021          2455710.0     25849.578947  7023.632328  73.932972
# 2  2022          2467003.5     27109.928571  7403.998331  81.362619
# 3  2023          2770628.0     24737.750000  8573.792542  76.551719
# 4  2024          2303943.0     24773.580645  6984.119068  75.098054

# %% [markdown]
# ##Interpretation of Yearly trend of water consumption and Yearly trend of water cost
#
#
# These two charts together give both a macro view (total consumption across all users) and a micro view (average cost per customer).
#
# By comparing them, we can answer questions like:
#
# Does higher total consumption always lead to higher average costs?
#
# Are costs rising due to price changes rather than consumption changes?
#
# Is water demand steady, seasonal, or growing?
#
# In short, the charts provide time-trend insights into how water consumption and costs evolve year by year — useful for forecasting, policy planning, and resource management.

# %%
# Group by Borough (or Region)
borough_analysis = df.groupby("Borough").agg({
    consumption_col: 'sum',
    cost_col: 'sum'
}).reset_index()

print(borough_analysis)
# Out:
#          Borough  ConsumptionGallons      CostUSD
# 0          Bronx           2221808.0  6570.587294
# 1       Brooklyn           2481103.0  7351.133900
# 2      Manhattan           2680432.0  7934.210123
# 3         Queens           2606243.0  7848.283865
# 4  Staten Island           3017161.0  9228.404095
# /tmp/ipython-input-538158942.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   borough_analysis = df.groupby("Borough").agg({

# %%
# Plot total consumption by borough
plt.figure(figsize=(10,6))
sns.barplot(data=borough_analysis, x="Borough", y=consumption_col, palette="Blues_d")
plt.title("Total Water Consumption by Borough")
plt.xlabel("Borough")
plt.ylabel("Total Consumption (Gallons)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2355340860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=borough_analysis, x="Borough", y=consumption_col, palette="Blues_d")

# %%
# Plot total cost by borough
plt.figure(figsize=(10,6))
sns.barplot(data=borough_analysis, x="Borough", y=cost_col, palette="Reds_d")
plt.title("Total Water Cost by Borough")
plt.xlabel("Borough")
plt.ylabel("Total Cost (USD)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1147180697.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=borough_analysis, x="Borough", y=cost_col, palette="Reds_d")

# %% [markdown]
# ##Interpretation of the Bar charts
#
# Chart type :Bar chart
#
# This chart aggregates watrough and produces two clear bar charts.
#
# One shows where the most water is consumed,and the other shows where the most money is spent.
#
# Features used:
#
# X-axis -->Borough
#
# Y-axis-->Total water consumption and Total cost of water in USD.
#
# They help compare consumption vs.cost distribution across regions.

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation

# %%
# your stage 4 pdf Link

https://drive.google.com/file/d/1i1jrE3q--N7jtAREeWRH0YLIwx9nMK2i/view?usp=drive_link

# %% [markdown]
# # Future Enhancement
#
# Use a Larger / Updated Dataset
#
# The current dataset gives good insights, but adding more years of data or real-time data feeds would give a stronger view of changing consumption and cost trends.
#
# For example, future data can show how new policies, population growth, or seasonal effects impact water usage.
#
# Integration with External Data Sources
#
# Combine water consumption data with weather data, population density, or income levels to find deeper correlations.
#
# This helps to understand external factors driving consumption and cost differences.
#
# Predictive Analytics (Forecasting)
#
# Apply machine learning models to predict future water consumption and costs.
#
# This helps organizations plan resources better and manage costs effectively.
#
# Interactive Dashboards
#
# Currently, charts are static, but future versions can include interactive filters (by year, borough, or property type).
#
# Users can drill down into specific areas for more personalized insights.
#
# Automation & Alerts
#
# Automate monthly/quarterly reports using Power BI service.
#
# Set up alerts to notify if water consumption crosses a certain limit or if costs rise sharply.
#
# Advanced Visualizations
#
# Add heatmaps for borough-level analysis.
#
# Use time-series forecasting visuals in Power BI to show future predictions.

# %% [markdown]
# # Conclusion
#
# In this project, I started with a messy raw dataset that contained water consumption and cost records. Through data cleaning, transformation, and visualization, I successfully converted it into a well-structured and meaningful dashboard.
#
# The key steps included:
#
# Removing duplicates and errors.
#
# Standardizing column names and formats.
#
# Grouping data by property type, borough, and year to find patterns.
#
# Creating clear visualizations (bar charts, line charts, scatter plots, boxplots) in Power BI.
#
# The final dashboard provides:
#
# Trends of water consumption and cost over time.
#
# Comparisons across property types and boroughs.
#
# Relationships between consumption and cost.
#
# This transformation shows how raw messy data can be turned into valuable business insights. The findings highlight the main factors influencing water usage and costs, giving decision-makers a strong foundation for planning and resource management.
